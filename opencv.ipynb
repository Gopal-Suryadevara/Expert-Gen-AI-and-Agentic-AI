# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\Acer\Desktop\horse.jpg")

# %%
input
# Out:
# array([[[255, 255, 239],
#         [254, 254, 238],
#         [255, 254, 240],
#         ...,
#         [104, 202, 236],
#         [ 86, 194, 218],
#         [ 73, 178, 199]],
#
#        [[254, 254, 238],
#         [254, 254, 238],
#         [254, 254, 238],
#         ...,
#         [115, 216, 255],
#         [111, 213, 242],
#         [ 80, 194, 211]],
#
#        [[254, 253, 239],
#         [254, 253, 239],
#         [254, 254, 238],
#         ...,
#         [118, 219, 251],
#         [125, 217, 242],
#         [ 96, 189, 204]],
#
#        ...,
#
#        [[134, 168, 181],
#         [126, 159, 175],
#         [120, 159, 181],
#         ...,
#         [111, 161, 167],
#         [114, 162, 174],
#         [115, 165, 171]],
#
#        [[143, 177, 190],
#         [123, 159, 169],
#         [125, 164, 179],
#         ...,
#         [119, 161, 168],
#         [112, 163, 166],
#         [116, 169, 172]],
#
#        [[155, 190, 200],
#         [129, 177, 179],
#         [122, 160, 162],
# ...

# %%
cv2.imshow("Stallion", input) #to display the image in a window named "Stallion"

cv2.waitKey() #to wait until a key is pressed to close the window

cv2.destroyAllWindows() #to close all the windows opened by OpenCV

# %%
print('Height of the image is: ', int(input.shape[0]), 'pixels')
print('Width of the image is: ', int(input.shape[1]), 'pixels')
# Out:
# Height of the image is:  800 pixels
# Width of the image is:  610 pixels

# %%
cv2.imwrite('Stallion.jpg', input) # Save the image to the current directory
# Out:
# True

# %%
import os
os.getcwd() # Get the current working directory
# Out:
# 'c:\\Users\\Acer\\AVSCODE\\Streamlit'

# %%
delete_path = r"c:\\Users\\Acer\\AVSCODE\\Streamlit\\output.jpg"
if os.path.exists(delete_path):
    os.remove(delete_path) # Delete the image file
    print("The image has been deleted.")
# Out:
# The image has been deleted.
